# %% [markdown]
# # Web Scraping IMDB movies based on adjusted URL

# %% [markdown]
# ## Loading the libraries

# %%
import pandas as pd
import numpy as np

import requests
from requests import get
from bs4 import BeautifulSoup

from time import sleep
from random import randint

# %% [markdown]
# ## Scraping from the web page

# %%
# Creating the lists we want to write into
titles = []
years = []
time = []
imdb_ratings = []
metascores = []
votes = []
us_gross = []
directors = []

# %%
# Getting English translated titles from the movies
headers = {'Accept-Language': 'en-US, en;q=0.5'}

# %%
pages = np.arange(1, 1001, 50)
pages
# Out:
# array([  1,  51, 101, 151, 201, 251, 301, 351, 401, 451, 501, 551, 601,
#        651, 701, 751, 801, 851, 901, 951])

# %% [markdown]
# # Change genres and num of votes in the URL to to get different results

# %%
# Storing each of the urls of 50 movies
for page in pages:
    # Getting the contents from the each url
    page = requests.get('https://www.imdb.com/search/title/?genres=horror&sort=user_rating,desc&title_type=feature&num_votes=30000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1' + str(page) + '&ref_=adv_nxt', headers=headers)
    soup = BeautifulSoup(page.text, 'html.parser')

    #https://www.imdb.com/search/title/?genres=horror&sort=user_rating,desc&title_type=feature&num_votes=30000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
    #https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=20000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
    #https://www.imdb.com/search/title/?genres=comedy&sort=user_rating,desc&title_type=feature&num_votes=10000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
    #https://www.imdb.com/search/title/?genres=sci_fi&sort=user_rating,desc&title_type=feature&num_votes=30000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
    #https://www.imdb.com/search/title/?genres=horror&sort=user_rating,desc&title_type=feature&num_votes=30000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
    #https://www.imdb.com/search/title/?genres=crime&sort=user_rating,desc&title_type=feature&num_votes=30000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
    #https://www.imdb.com/search/title/?genres=mystery&sort=user_rating,desc&title_type=feature&num_votes=30000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
    #https://www.imdb.com/search/title/?genres=biography&sort=user_rating,desc&title_type=feature&num_votes=30000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1
    #https://www.imdb.com/search/title/?groups=top_1000&start=
    #history, music, drama, adventure, sports, fantasy,

    # Aiming the part of the html we want to get the information from
    movie_div = soup.find_all('div', class_='lister-item mode-advanced')

    # Controling the loop’s rate by pausing the execution of the loop for a specified amount of time
    # Waiting time between requests for a number between 2-10 seconds
    sleep(randint(2,10))

    for container in movie_div:
        # Scraping the movie's name
        name = container.h3.a.text
        titles.append(name)

        # Scraping the movie's year
        year = container.h3.find('span', class_='lister-item-year').text
        years.append(year)

        # Scraping the movie's length
        runtime = container.find('span', class_='runtime').text if container.p.find('span', class_='runtime') else '-'
        time.append(runtime)

        # Scraping the rating
        imdb = float(container.strong.text)
        imdb_ratings.append(imdb)

        # Scraping the metascore
        m_score = container.find('span', class_='metascore').text if container.find('span', class_='metascore') else '-'
        metascores.append(m_score)

        # Scraping votes and gross earnings
        nv = container.find_all('span', attrs={'name':'nv'})
        vote = nv[0].text
        votes.append(vote)
        grosses = nv[1].text if len(nv) > 1 else '-'
        us_gross.append(grosses)

        # Scraping the director(s)
        #director = container.find('span', class_='')
        #directors.append(director)

# %% [markdown]
# # Manual option for single values or specific directors, actors, producers, etc.

# %%
# Send an HTTP request to the webpage
url = 'https://www.imdb.com/search/title/?genres=horror&sort=user_rating,desc&title_type=feature&num_votes=30000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=GMJM46PTFY8D7B4S5199&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1'
response = requests.get(url)

# Parse the HTML content of the page
soup = BeautifulSoup(response.text, 'html.parser')

# Find the element with a specific class attribute comment out below before use
##element = soup.find('tag_name', class_='class_name')

# %% [markdown]
# ## Creating the Data Set

# %%
movies = pd.DataFrame({'movie':titles,
                       'year':years,
                       'time_minute':time,
                       'imdb_rating':imdb_ratings,
                       'metascore':metascores,
                       'vote':votes,
                       'gross_earning':us_gross})

movies.head()
# Out:
#          movie    year time_minute  imdb_rating   metascore       vote  \
# 0        Alien  (1979)     117 min          8.5  89            924,035
# 1       Psycho  (1960)     109 min          8.5  97            702,331
# 2  The Shining  (1980)     146 min          8.4  66          1,076,371
# 3    The Thing  (1982)     109 min          8.2  57            450,886
# 4      Tumbbad  (2018)     104 min          8.2           -     55,878
#
#   gross_earning
# 0       $78.90M
# 1       $32.00M
# 2       $44.02M
# 3       $13.78M
# 4             -

# %%
movies.dtypes
# Out:
# movie             object
# year              object
# time_minute       object
# imdb_rating      float64
# metascore         object
# vote              object
# gross_earning     object
# dtype: object

# %% [markdown]
# ## Cleaning the Data Set

# %%
# Cleaning 'year' column
movies['year'] = movies['year'].str.extract('(\d+)').astype(int)
movies.head(3)
# Out:
#          movie  year time_minute  imdb_rating   metascore       vote  \
# 0        Alien  1979     117 min          8.5  89            924,035
# 1       Psycho  1960     109 min          8.5  97            702,331
# 2  The Shining  1980     146 min          8.4  66          1,076,371
#
#   gross_earning
# 0       $78.90M
# 1       $32.00M
# 2       $44.02M

# %%
# Cleaning 'time_minute' column
movies['time_minute'] = movies['time_minute'].str.extract('(\d+)').astype(int)
movies.head(3)
# Out:
#          movie  year  time_minute  imdb_rating   metascore       vote  \
# 0        Alien  1979          117          8.5  89            924,035
# 1       Psycho  1960          109          8.5  97            702,331
# 2  The Shining  1980          146          8.4  66          1,076,371
#
#   gross_earning
# 0       $78.90M
# 1       $32.00M
# 2       $44.02M

# %%
# Cleaning 'metascore' column
movies['metascore'] = movies['metascore'].str.extract('(\d+)')
# convert it to float and if there are dashes turn it into NaN
movies['metascore'] = pd.to_numeric(movies['metascore'], errors='coerce')

# %%
# Cleaning 'vote' column
movies['vote'] = movies['vote'].str.replace(',', '').astype(int)
movies.head(3)
# Out:
#          movie  year  time_minute  imdb_rating  metascore     vote  \
# 0        Alien  1979          117          8.5       89.0   924035
# 1       Psycho  1960          109          8.5       97.0   702331
# 2  The Shining  1980          146          8.4       66.0  1076371
#
#   gross_earning
# 0       $78.90M
# 1       $32.00M
# 2       $44.02M

# %%
# Cleaning 'gross_earning' column
# left strip $ and right strip M
movies['gross_earning'] = movies['gross_earning'].map(lambda x: x.lstrip('$').rstrip('M'))
# convert it to float and if there are dashes turn it into NaN
movies['gross_earning'] = pd.to_numeric(movies['gross_earning'], errors='coerce')
movies.head(3)
# Out:
#          movie  year  time_minute  imdb_rating  metascore     vote  \
# 0        Alien  1979          117          8.5       89.0   924035
# 1       Psycho  1960          109          8.5       97.0   702331
# 2  The Shining  1980          146          8.4       66.0  1076371
#
#    gross_earning
# 0          78.90
# 1          32.00
# 2          44.02

# %%
movies.dtypes
# Out:
# movie             object
# year               int64
# time_minute        int64
# imdb_rating      float64
# metascore        float64
# vote               int64
# gross_earning    float64
# dtype: object

# %% [markdown]
# ## Final Data Set

# %%
movies
# Out:
#                        movie  year  time_minute  imdb_rating  metascore  \
# 0                      Alien  1979          117          8.5       89.0
# 1                     Psycho  1960          109          8.5       97.0
# 2                The Shining  1980          146          8.4       66.0
# 3                  The Thing  1982          109          8.2       57.0
# 4                    Tumbbad  2018          104          8.2        NaN
# ..                       ...   ...          ...          ...        ...
# 995                 The Crow  1994          102          7.5       71.0
# 996           The Wicker Man  1973           88          7.5       87.0
# 997  Tucker and Dale vs Evil  2010           89          7.5       65.0
# 998               Dead Alive  1992          104          7.5       54.0
# 999               Grindhouse  2007          191          7.5       77.0
#
#         vote  gross_earning
# 0     924035          78.90
# 1     702331          32.00
# ...

# %% [markdown]
# ## Saving the data to a csv file

# %%
movies.to_csv('top_rated_horror_movies.csv')

# %%
def getSeasonsCount(input_url):
    """
    Function to get total no of seasons present in the input series
    Parameters:
    input_url: URL to scrape from
    Returns:
    Total number of seasons (int)
    """
    url = "https://www.imdb.com/title/tt8111088/?ref_=nv_sr_srsg_4_tt_4_nm_4_q_manda"
    try:
        response = requests.get(url)
        season_page = BeautifulSoup(response.content)
        seasonsSelect = season_page.find('div',attrs={'class':'episode-list-select'}).find('select', attrs={'id':'bySeason'})
        optionsVal = [int(option.text.strip()) for option in seasonsSelect.findAll('option')]
        return max(optionsVal)
    except:
        print("Error in connecting to the website")
        print("Possibly because the series doesn't exist")
        return -1

# %%
# For scraping from all the seasons
def scrape_all_data(input_url):
    """
    Function that will scrape all the episodes data from a series
    Parameters:
    input_url: URL to scrape from
    Returns:
    dictionary containing scraped data
    """
    no_of_seasons = getSeasonsCount(input_url)
    print(f'There are {no_of_seasons} seasons in this series')
    if no_of_seasons < 0 :
        return -1
    season_no_list = []
    episode_no_list = []
    episode_name_list = []
    episode_airdate_list = []
    episode_score_list = []
    episode_votes_list = []
    for season in range(no_of_seasons):
        season_no = season+1
        print(f"Parsing Season {season_no}")
        # Retreive website Data
        url = f'{input_url}?season={season_no}'
        response = requests.get(url)
        season_page = BeautifulSoup(response.content)
        episodes = season_page.findAll('div',attrs={'class':'info'})
        print(f'There are {len(episodes)} episodes in season {season_no}')
        for episode_no, episode in enumerate(episodes):
            # episode_name
            episode_name = episode.strong.a.text.strip()
            # episode_airdata
            episode_airdate = episode.find('div',attrs={'class':'airdate'}).text.strip().replace('.','')
            # episode_score
            try:
                episode_score = episode.find(
                'div',attrs={'class':'ipl-rating-widget'}
                ).find(
                    'div',attrs={'class':'ipl-rating-star small'}
                ).find('span',attrs={'class':'ipl-rating-star__rating'}).text
            except:
                episode_score= 0

            # episode_votes
            try:
                episode_votes = episode.find(
                'div',attrs={'class':'ipl-rating-widget'}
                ).find(
                    'div',attrs={'class':'ipl-rating-star small'}
                ).find('span',attrs={'class':'ipl-rating-star__total-votes'}).text.strip('()').replace(',','')
            except:
                episode_votes = 0
            # print(f'------------------- Episode {episode_no+1} -------------------')
            # print(f'Episode Name: {episode_name}')
            # print(f'Episode Date: {episode_airdate}')
            # print(f'Episode Score: {episode_score}')
            # print(f'Episode Votes: {episode_votes}')
            # print('--------------------------------------------------')

            # creating lists
            season_no_list.append(season_no)
            episode_no_list.append(episode_no+1)
            episode_name_list.append(episode_name)
            episode_airdate_list.append(episode_airdate)
            episode_score_list.append(episode_score)
            episode_votes_list.append(episode_votes)

    print('Parsing Done')
    # creating dictionary from list
    data_dict = {
        'season_no': season_no_list,
        'episode no': episode_no_list,
        'episode_name': episode_name_list,
        'episode_airdate': episode_airdate_list,
        'episode_score': episode_score_list,
        'episode_votes': episode_votes_list
    }

    return data_dict
