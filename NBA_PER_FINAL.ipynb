# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidWilliamSmith/Python/blob/main/NBA_PER_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nba_api
# !pip install tqdm
# Out:
# Collecting nba_api
#   Downloading nba_api-1.4.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: certifi<2024.0.0,>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from nba_api) (2023.7.22)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from nba_api) (1.23.5)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.10/dist-packages (from nba_api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->nba_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->nba_api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->nba_api) (2.0.7)
# Installing collected packages: nba_api
# Successfully installed nba_api-1.4.1
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)

# %%
from nba_api.stats.endpoints import leaguedashteamstats, playercareerstats
from nba_api.stats.static import players
import pandas as pd
import numpy as np
import time
import warnings
warnings.filterwarnings('ignore')
from nba_api.stats.endpoints import commonplayerinfo

def fetch_pace_data(season):
    team_stats = leaguedashteamstats.LeagueDashTeamStats(season=season, measure_type_detailed_defense='Advanced')
    team_data = team_stats.get_data_frames()[0]
    pace_data = team_data[['TEAM_NAME', 'PACE']]
    league_pace = pace_data['PACE'].mean()
    return pace_data, league_pace

def calculate_uPER(row):
    # Insert the detailed formula for uPER here
    uPER = (row['PTS'] + row['REB'] + row['AST'] - row['TOV']) / row['GP']
    return uPER

def calculate_aPER(uPER, team_pace, league_pace):
    aPER = uPER * (league_pace / team_pace)
    return aPER

def calculate_nPER(aPER, league_average_aPER):
    nPER = aPER * (15 / league_average_aPER)
    return nPER

# Function to get player position with a delay
def get_player_position(player_id):
    player_info = commonplayerinfo.CommonPlayerInfo(player_id=player_id)
    player_info_df = player_info.get_data_frames()[0]
    time.sleep(0.5)  # Half-second delay
    return player_info_df['POSITION'][0]

# Fetch active players and their positions
active_players_list = players.get_active_players()
active_players_df = pd.DataFrame(active_players_list)

#6 minutes
# Adding a position column to active_players_df
active_players_df['position'] = active_players_df['id'].apply(get_player_position)
active_players_df.head()
# Out:
#         id         full_name first_name last_name  is_active        position
# 0  1630173  Precious Achiuwa   Precious   Achiuwa       True         Forward
# 1   203500      Steven Adams     Steven     Adams       True          Center
# 2  1628389       Bam Adebayo        Bam   Adebayo       True  Center-Forward
# 3  1630534      Ochai Agbaji      Ochai    Agbaji       True           Guard
# 4  1630583      Santi Aldama      Santi    Aldama       True  Forward-Center

# %%
from tqdm import tqdm

# Fetch player stats and team pace data
season = '2022-23'  # specify the season
team_pace_data, league_pace = fetch_pace_data(season)
all_players_stats_df = pd.DataFrame()

# about 7 minutes
# Loop with tqdm for progress indication
all_players_stats_list = []
for player in tqdm(active_players_list, desc="Processing Players"):
    player_stats = playercareerstats.PlayerCareerStats(player_id=player['id'])
    player_stats_df = player_stats.get_data_frames()[0]
    player_stats_df = player_stats_df[player_stats_df['SEASON_ID'] == '2022-23']  # Filter for 2022-23 season
    all_players_stats_list.append(player_stats_df)
    time.sleep(0.5)  # Delay to prevent rate limiting

all_players_stats_df = pd.concat(all_players_stats_list)
# Check if all_players_stats_df is empty
print("All Players Stats DataFrame:")
print(all_players_stats_df.head())
# Out:
# Processing Players: 100%|██████████| 531/531 [07:40<00:00,  1.15it/s]
# All Players Stats DataFrame:
#   PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  GP  \
# 2   1630173   2022-23        00  1610612761               TOR        23.0  55
# 9    203500   2022-23        00  1610612763               MEM        29.0  42
# 5   1628389   2022-23        00  1610612748               MIA        25.0  75
# 0   1630534   2022-23        00  1610612762               UTA        23.0  59
# 1   1630583   2022-23        00  1610612763               MEM        22.0  77
#
#    GS     MIN  FGM  ... FT_PCT  OREB DREB  REB  AST STL BLK  TOV   PF   PTS
# 2  12  1141.0  196  ...  0.702   100  228  328   50  31  30   59  102   508
# 9  42  1133.0  157  ...  0.364   214  271  485   97  36  46   79   98   361
# 5  75  2598.0  602  ...  0.806   184  504  688  240  88  61  187  208  1529
# 0  22  1209.0  165  ...  0.812    43   78  121   67  16  15   41   99   467
# 1  20  1682.0  247  ...  0.750    85  286  371   97  45  48   60  143   696
#
# [5 rows x 27 columns]

# %%
team_name_mapping = {
    'ATL': 'Atlanta Hawks',
    'BOS': 'Boston Celtics',
    'BKN': 'Brooklyn Nets',
    'CHA': 'Charlotte Hornets',
    'CHI': 'Chicago Bulls',
    'CLE': 'Cleveland Cavaliers',
    'DAL': 'Dallas Mavericks',
    'DEN': 'Denver Nuggets',
    'DET': 'Detroit Pistons',
    'GSW': 'Golden State Warriors',
    'HOU': 'Houston Rockets',
    'IND': 'Indiana Pacers',
    'LAC': 'LA Clippers',
    'LAL': 'Los Angeles Lakers',
    'MEM': 'Memphis Grizzlies',
    'MIA': 'Miami Heat',
    'MIL': 'Milwaukee Bucks',
    'MIN': 'Minnesota Timberwolves',
    'NOP': 'New Orleans Pelicans',
    'NYK': 'New York Knicks',
    'OKC': 'Oklahoma City Thunder',
    'ORL': 'Orlando Magic',
    'PHI': 'Philadelphia 76ers',
    'PHX': 'Phoenix Suns',
    'POR': 'Portland Trail Blazers',
    'SAC': 'Sacramento Kings',
    'SAS': 'San Antonio Spurs',
    'TOR': 'Toronto Raptors',
    'UTA': 'Utah Jazz',
    'WAS': 'Washington Wizards'
}

# Apply the mapping
all_players_stats_df['TEAM_NAME'] = all_players_stats_df['TEAM_ABBREVIATION'].map(team_name_mapping)

# Merge with team pace data, player details, and position
# merged_df = pd.merge(all_players_stats_df, active_players_df[['id', 'full_name', 'position']], how='left', left_on='PLAYER_ID', right_on='id')
# merged_df = pd.merge(merged_df, team_pace_data[['TEAM_NAME', 'PACE']], how='left', left_on='TEAM_ABBREVIATION', right_on='TEAM_NAME')
# Now perform the merge
merged_df = pd.merge(all_players_stats_df, active_players_df[['id', 'full_name', 'position']], how='left', left_on='PLAYER_ID', right_on='id')
merged_df = pd.merge(merged_df, team_pace_data[['TEAM_NAME', 'PACE']], how='left', on='TEAM_NAME')

# Check merged DataFrame
print("Merged DataFrame:")
print(merged_df.head())

# Recalculate PER metrics
merged_df['uPER'] = merged_df.apply(calculate_uPER, axis=1)
merged_df['aPER'] = merged_df.apply(lambda row: calculate_aPER(row['uPER'], row['PACE'], league_pace) if pd.notnull(row['PACE']) else np.nan, axis=1)
league_average_aPER = merged_df['aPER'].mean(skipna=True)
merged_df['nPER'] = merged_df.apply(lambda row: calculate_nPER(row['aPER'], league_average_aPER) if pd.notnull(row['aPER']) else np.nan, axis=1)

# Final DataFrame with position
final_df = merged_df[['PLAYER_ID', 'full_name', 'position', 'PLAYER_AGE', 'uPER', 'aPER', 'nPER']]
print("Final DataFrame:")
final_df.head()
# Out:
# Merged DataFrame:
#   PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  GP  \
# 0   1630173   2022-23        00  1610612761               TOR        23.0  55
# 1    203500   2022-23        00  1610612763               MEM        29.0  42
# 2   1628389   2022-23        00  1610612748               MIA        25.0  75
# 3   1630534   2022-23        00  1610612762               UTA        23.0  59
# 4   1630583   2022-23        00  1610612763               MEM        22.0  77
#
#    GS     MIN  FGM  ... STL  BLK  TOV   PF   PTS          TEAM_NAME       id  \
# 0  12  1141.0  196  ...  31   30   59  102   508    Toronto Raptors  1630173
# 1  42  1133.0  157  ...  36   46   79   98   361  Memphis Grizzlies   203500
# 2  75  2598.0  602  ...  88   61  187  208  1529         Miami Heat  1628389
# 3  22  1209.0  165  ...  16   15   41   99   467          Utah Jazz  1630534
# 4  20  1682.0  247  ...  45   48   60  143   696  Memphis Grizzlies  1630583
#
#           full_name        position    PACE
# 0  Precious Achiuwa         Forward   97.85
# 1      Steven Adams          Center  101.50
# 2       Bam Adebayo  Center-Forward   96.76
# 3      Ochai Agbaji           Guard  101.02
# 4      Santi Aldama  Forward-Center  101.50
#
# [5 rows x 32 columns]
# Final DataFrame:
#   PLAYER_ID         full_name        position  PLAYER_AGE       uPER  \
# 0   1630173  Precious Achiuwa         Forward        23.0  15.036364
# 1    203500      Steven Adams          Center        29.0  20.571429
# 2   1628389       Bam Adebayo  Center-Forward        25.0  30.266667
# 3   1630534      Ochai Agbaji           Guard        23.0  10.406780
# 4   1630583      Santi Aldama  Forward-Center        22.0  14.337662
#
#         aPER       nPER
# 0  15.334735  15.319578
# 1  20.225194  20.205203
# 2  31.214976  31.184123
# 3  10.280240  10.270079
# 4  14.096347  14.082414

# %%
print(all_players_stats_df['TEAM_ABBREVIATION'].unique())
print(team_pace_data['TEAM_NAME'].unique())
# Out:
# ['TOR' 'MEM' 'MIA' 'UTA' 'MIN' 'TOT' 'MIL' 'CLE' 'NOP' 'ORL' 'NYK' 'POR'
#  'WAS' 'PHX' 'DET' 'GSW' 'CHA' 'LAL' 'SAS' 'SAC' 'LAC' 'DAL' 'CHI' 'ATL'
#  'IND' 'DEN' 'BKN' 'BOS' 'OKC' 'PHI' 'HOU']
# ['Atlanta Hawks' 'Boston Celtics' 'Brooklyn Nets' 'Charlotte Hornets'
#  'Chicago Bulls' 'Cleveland Cavaliers' 'Dallas Mavericks' 'Denver Nuggets'
#  'Detroit Pistons' 'Golden State Warriors' 'Houston Rockets'
#  'Indiana Pacers' 'LA Clippers' 'Los Angeles Lakers' 'Memphis Grizzlies'
#  'Miami Heat' 'Milwaukee Bucks' 'Minnesota Timberwolves'
#  'New Orleans Pelicans' 'New York Knicks' 'Oklahoma City Thunder'
#  'Orlando Magic' 'Philadelphia 76ers' 'Phoenix Suns'
#  'Portland Trail Blazers' 'Sacramento Kings' 'San Antonio Spurs'
#  'Toronto Raptors' 'Utah Jazz' 'Washington Wizards']

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 546 entries, 0 to 545
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PLAYER_ID   546 non-null    object
#  1   full_name   546 non-null    object
#  2   position    546 non-null    object
#  3   PLAYER_AGE  546 non-null    float64
#  4   uPER        546 non-null    float64
#  5   aPER        490 non-null    float64
#  6   nPER        490 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 34.1+ KB

# %%
print(final_df.columns)
# Out:
# Index(['PLAYER_ID', 'full_name', 'position', 'PLAYER_AGE', 'uPER', 'aPER',
#        'nPER'],
#       dtype='object')

# %%
top_players_by_position = {}
positions = merged_df['position'].unique()

for position in positions:
    top_players = merged_df[merged_df['position'] == position].sort_values(by='nPER', ascending=False).head(5)
    top_players_by_position[position] = top_players

combined_df = pd.concat(top_players_by_position.values())

import plotly.express as px

fig = px.bar(combined_df, x='full_name', y='nPER', color='position', barmode='group',
             hover_data=['PLAYER_AGE', 'TEAM_ABBREVIATION'], title='Top 5 Players by nPER in Each Position')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4c1470f1-65f9-48df-96f3-bb48fe7a280c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c1470f1-65f9-48df-96f3-bb48fe7a280c")) {                    Plotly.newPlot(                        "4c1470f1-65f9-48df-96f3-bb48fe7a280c",                        [{"alignmentgroup":"True","customdata":[[28.0,"MIL"],[38.0,"LAL"],[34.0,"BKN"],[29.0,"TOR"],[22.0,"NOP"]],"hovertemplate":"position=Forward\u003cbr\u003efull_name=%{x}\u003cbr\u003enPER=%{y}\u003cbr\u003ePLAYER_AGE=%{customdata[0]}\u003cbr\u003eTEAM_ABBREVIATION=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Forward","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Forward","offsetgroup":"Forward","orientation":"v","showlegend":true,"textposition":"auto","x":["Giannis Antetokounmpo","LeBron James","Kevin Durant","Pascal Siakam","Zion Williamson"],"xaxis":"x","y":[43.89310392545907,39.90851327147935,38.588045655695915,36.19017678193132,34.17668029169847],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[28.0,"DEN"],[32.0,"CHI"],[24.0,"PHX"],[22.0,"CLE"],[25.0,"CLE"]],"hovertemplate":"position=Center\u003cbr\u003efull_name=%{x}\u003cbr\u003enPER=%{y}\u003cbr\u003ePLAYER_AGE=%{customdata[0]}\u003cbr\u003eTEAM_ABBREVIATION=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Center","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Center","offsetgroup":"Center","orientation":"v","showlegend":true,"textposition":"auto","x":["Nikola Jokic","Nikola Vucevic","Deandre Ayton","Evan Mobley","Jarrett Allen"],"xaxis":"x","y":[42.99068636439095,30.35131311278379,28.07889669927371,27.081770605936622,25.203619511084106],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[29.0,"PHI"],[25.0,"MIA"],[27.0,"MIN"],[27.0,"IND"],[24.0,"ORL"]],"hovertemplate":"position=Center-Forward\u003cbr\u003efull_name=%{x}\u003cbr\u003enPER=%{y}\u003cbr\u003ePLAYER_AGE=%{customdata[0]}\u003cbr\u003eTEAM_ABBREVIATION=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Center-Forward","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Center-Forward","offsetgroup":"Center-Forward","orientation":"v","showlegend":true,"textposition":"auto","x":["Joel Embiid","Bam Adebayo","Karl-Anthony Towns","Myles Turner","Wendell Carter Jr."],"xaxis":"x","y":[44.97087306060566,31.18412302681464,30.196160825537707,24.748672910476618,24.41159704185831],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[32.0,"POR"],[24.0,"OKC"],[35.0,"GSW"],[31.0,"DAL"],[23.0,"MEM"]],"hovertemplate":"position=Guard\u003cbr\u003efull_name=%{x}\u003cbr\u003enPER=%{y}\u003cbr\u003ePLAYER_AGE=%{customdata[0]}\u003cbr\u003eTEAM_ABBREVIATION=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Guard","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Guard","offsetgroup":"Guard","orientation":"v","showlegend":true,"textposition":"auto","x":["Damian Lillard","Shai Gilgeous-Alexander","Stephen Curry","Kyrie Irving","Ja Morant"],"xaxis":"x","y":[41.165697062994234,38.010923588294354,37.53523597705243,37.022100874676326,36.06757488005121],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[30.0,"LAL"],[28.0,"NYK"],[27.0,"SAC"],[26.0,"UTA"],[27.0,"WAS"]],"hovertemplate":"position=Forward-Center\u003cbr\u003efull_name=%{x}\u003cbr\u003enPER=%{y}\u003cbr\u003ePLAYER_AGE=%{customdata[0]}\u003cbr\u003eTEAM_ABBREVIATION=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Forward-Center","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Forward-Center","offsetgroup":"Forward-Center","orientation":"v","showlegend":true,"textposition":"auto","x":["Anthon ...

# %%
import plotly.express as px

fig = px.scatter(combined_df, x='PLAYER_AGE', y='nPER', color='position',
                 symbol='TEAM_ABBREVIATION',
                 title='Player Age vs Performance (nPER)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bad4d5a8-44e4-4eb5-ba69-ac3bc1b3683f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bad4d5a8-44e4-4eb5-ba69-ac3bc1b3683f")) {                    Plotly.newPlot(                        "bad4d5a8-44e4-4eb5-ba69-ac3bc1b3683f",                        [{"hovertemplate":"position=Forward\u003cbr\u003eTEAM_ABBREVIATION=MIL\u003cbr\u003ePLAYER_AGE=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Forward, MIL","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Forward, MIL","orientation":"v","showlegend":true,"x":[28.0],"xaxis":"x","y":[43.89310392545907],"yaxis":"y","type":"scatter"},{"hovertemplate":"position=Forward\u003cbr\u003eTEAM_ABBREVIATION=LAL\u003cbr\u003ePLAYER_AGE=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Forward, LAL","marker":{"color":"#636efa","symbol":"diamond"},"mode":"markers","name":"Forward, LAL","orientation":"v","showlegend":true,"x":[38.0],"xaxis":"x","y":[39.90851327147935],"yaxis":"y","type":"scatter"},{"hovertemplate":"position=Forward\u003cbr\u003eTEAM_ABBREVIATION=BKN\u003cbr\u003ePLAYER_AGE=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Forward, BKN","marker":{"color":"#636efa","symbol":"square"},"mode":"markers","name":"Forward, BKN","orientation":"v","showlegend":true,"x":[34.0],"xaxis":"x","y":[38.588045655695915],"yaxis":"y","type":"scatter"},{"hovertemplate":"position=Forward\u003cbr\u003eTEAM_ABBREVIATION=TOR\u003cbr\u003ePLAYER_AGE=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Forward, TOR","marker":{"color":"#636efa","symbol":"x"},"mode":"markers","name":"Forward, TOR","orientation":"v","showlegend":true,"x":[29.0],"xaxis":"x","y":[36.19017678193132],"yaxis":"y","type":"scatter"},{"hovertemplate":"position=Forward\u003cbr\u003eTEAM_ABBREVIATION=NOP\u003cbr\u003ePLAYER_AGE=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Forward, NOP","marker":{"color":"#636efa","symbol":"cross"},"mode":"markers","name":"Forward, NOP","orientation":"v","showlegend":true,"x":[22.0],"xaxis":"x","y":[34.17668029169847],"yaxis":"y","type":"scatter"},{"hovertemplate":"position=Center\u003cbr\u003eTEAM_ABBREVIATION=DEN\u003cbr\u003ePLAYER_AGE=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Center, DEN","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Center, DEN","orientation":"v","showlegend":true,"x":[28.0],"xaxis":"x","y":[42.99068636439095],"yaxis":"y","type":"scatter"},{"hovertemplate":"position=Center\u003cbr\u003eTEAM_ABBREVIATION=CHI\u003cbr\u003ePLAYER_AGE=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Center, CHI","marker":{"color":"#EF553B","symbol":"diamond"},"mode":"markers","name":"Center, CHI","orientation":"v","showlegend":true,"x":[32.0],"xaxis":"x","y":[30.35131311278379],"yaxis":"y","type":"scatter"},{"hovertemplate":"position=Center\u003cbr\u003eTEAM_ABBREVIATION=PHX\u003cbr\u003ePLAYER_AGE=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Center, PHX","marker":{"color":"#EF553B","symbol":"square"},"mode":"markers","name":"Center, PHX","orientation":"v","showlegend":true,"x":[24.0],"xaxis":"x","y":[28.07889669927371],"yaxis":"y","type":"scatter"},{"hovertemplate":"position=Center\u003cbr\u003eTEAM_ABBREVIATION=CLE\u003cbr\u003ePLAYER_AGE=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Center, CLE","marker":{"color":"#EF553B","symbol":"x"},"mode":"markers","name":"Center, CLE","orientation":"v","showlegend":true,"x":[22.0,25.0 ...

# %%
# Calculate team average nPER
team_avg_nPER = combined_df.groupby('TEAM_ABBREVIATION')['nPER'].mean().reset_index()

fig = px.bar(team_avg_nPER, x='TEAM_ABBREVIATION', y='nPER',
             title='Team Average nPER')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="401813a2-0268-4292-99a3-eaf195c8e49a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("401813a2-0268-4292-99a3-eaf195c8e49a")) {                    Plotly.newPlot(                        "401813a2-0268-4292-99a3-eaf195c8e49a",                        [{"alignmentgroup":"True","hovertemplate":"TEAM_ABBREVIATION=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["BKN","BOS","CHI","CLE","DAL","DEN","GSW","IND","LAL","MEM","MIA","MIL","MIN","NOP","NYK","OKC","ORL","PHI","PHX","POR","SAC","SAS","TOR","UTA","WAS"],"xaxis":"x","y":[35.181864861361625,37.49477580706611,31.360295823400115,26.142695058510363,41.81884499455066,42.99068636439095,37.53523597705243,24.748672910476618,38.984511016550584,36.06757488005121,31.18412302681464,43.89310392545907,30.196160825537707,34.17668029169847,31.388405604589067,38.010923588294354,24.41159704185831,44.97087306060566,26.027153112903473,41.165697062994234,35.31274636143767,25.53282790219953,30.71806044029435,33.74776842870887,32.295753425492535],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outline ...

# %%
# Load the CSV file containing player salaries
salary_df = pd.read_csv('https://raw.githubusercontent.com/fenago/datasets/main/nba_team_money202223.csv')

# Remove leading and trailing spaces from column names
salary_df.columns = salary_df.columns.str.strip()

# Rename columns for consistency
salary_df.rename(columns={'2022/23 ': 'Salary_2022_23', '2022/23(*)': 'Adjusted_Salary_2022_23'}, inplace=True)

# Assuming 'final_df', 'all_players_stats_df', and 'merged_df' are pre-loaded dataframes with player stats
# You would need to make sure 'final_df' and 'all_players_stats_df' are loaded with actual data before this step

# Merge salary data with the three dataframes using 'full_name' as the common column for merging
# enhanced_final_df = pd.merge(final_df, salary_df, how='left', on='full_name')
# enhanced_all_players_stats_df = pd.merge(all_players_stats_df, salary_df, how='left', on='full_name')
enhanced_merged_df = pd.merge(merged_df, salary_df, how='left', on='full_name')

# Renaming columns in the merged dataframes as required
# enhanced_final_df.rename(columns={'full_name': 'Full_Name'}, inplace=True)
# enhanced_all_players_stats_df.rename(columns={'full_name': 'Full_Name'}, inplace=True)
enhanced_merged_df.rename(columns={'full_name': 'Full_Name'}, inplace=True)

# Display the head of the merged dataframes to verify the merge and the renamed columns
# print(enhanced_final_df.head())
# print(enhanced_all_players_stats_df.head())
# Renaming the '2022/23' column to '2022_23_Salary'
enhanced_merged_df = enhanced_merged_df.rename(columns={'2022/23': '2022_23_Salary'})

# Verify the change
print(enhanced_merged_df.columns)

enhanced_merged_df.head()
# Out:
# Index(['PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS', 'TEAM_NAME', 'id', 'Full_Name', 'position',
#        'PACE', 'uPER', 'aPER', 'nPER', '2022_23_Salary',
#        'Adjusted_Salary_2022_23'],
#       dtype='object')
#   PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  GP  \
# 0   1630173   2022-23        00  1610612761               TOR        23.0  55
# 1    203500   2022-23        00  1610612763               MEM        29.0  42
# 2   1628389   2022-23        00  1610612748               MIA        25.0  75
# 3   1630534   2022-23        00  1610612762               UTA        23.0  59
# 4   1630583   2022-23        00  1610612763               MEM        22.0  77
#
#    GS     MIN  FGM  ...          TEAM_NAME       id         Full_Name  \
# 0  12  1141.0  196  ...    Toronto Raptors  1630173  Precious Achiuwa
# 1  42  1133.0  157  ...  Memphis Grizzlies   203500      Steven Adams
# 2  75  2598.0  602  ...         Miami Heat  1628389       Bam Adebayo
# 3  22  1209.0  165  ...          Utah Jazz  1630534      Ochai Agbaji
# 4  20  1682.0  247  ...  Memphis Grizzlies  1630583      Santi Aldama
#
#          position    PACE       uPER       aPER       nPER 2022_23_Salary  \
# 0         Forward   97.85  15.036364  15.334735  15.319578     $2,840,160
# 1          Center  101.50  20.571429  20.225194  20.205203    $17,926,829
# 2  Center-Forward   96.76  30.266667  31.214976  31.184123    $30,351,780
# 3           Guard  101.02  10.406780  10.280240  10.270079     $3,918,360
# 4  Forward-Center  101.50  14.337662  14.096347  14.082414            NaN
#
#   Adjusted_Salary_2022_23
# 0              $2,924,489
# 1             $18,459,108
# 2             $31,252,978
# 3              $4,034,703
# 4                     NaN
#
# [5 rows x 37 columns]

# %%
# Assuming enhanced_merged_df is your DataFrame
null_count = enhanced_merged_df['2022_23_Salary'].isnull().sum()
print("Number of null or NaN values in 2022_23_Salary:", null_count)
# Out:
# Number of null or NaN values in 2022_23_Salary: 57

# %%
# Check for columns with missing values and count them
missing_value_counts = enhanced_merged_df.isnull().sum()
columns_with_missing_values = missing_value_counts[missing_value_counts > 0]

print("Columns with missing values and their counts:")
print(columns_with_missing_values)
# Out:
# Columns with missing values and their counts:
# TEAM_NAME                  56
# PACE                       56
# aPER                       56
# nPER                       56
# 2022_23_Salary             57
# Adjusted_Salary_2022_23    57
# dtype: int64

# %%
import plotly.express as px

fig = px.scatter(enhanced_merged_df.dropna(subset=['nPER', '2022_23_Salary']),
                 x='2022_23_Salary', y='nPER', color='position',
                 hover_data=['Full_Name'], title='nPER vs. 2022_23_Salary by Position')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0c93ad9d-72b1-41e2-9399-60579a2ad532" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c93ad9d-72b1-41e2-9399-60579a2ad532")) {                    Plotly.newPlot(                        "0c93ad9d-72b1-41e2-9399-60579a2ad532",                        [{"customdata":[["Precious Achiuwa"],["Giannis Antetokounmpo"],["Thanasis Antetokounmpo"],["Deni Avdija"],["Paolo Banchero"],["Dalano Banton"],["Dominick Barlow"],["Harrison Barnes"],["Keita Bates-Diop"],["MarJon Beauchamp"],["Davis Bertans"],["Bojan Bogdanovic"],["Chris Boucher"],["Malaki Branham"],["Jimmy Butler"],["Jamal Cain"],["Vlatko Cancar"],["Julian Champagnie"],["Julian Champagnie"],["Brandon Clarke"],["Robert Covington"],["Torrey Craig"],["Jae Crowder"],["Moussa Diabate"],["Ousmane Dieng"],["Kevin Durant"],["Kevin Durant"],["Tari Eason"],["Kessler Edwards"],["Kessler Edwards"],["Dorian Finney-Smith"],["Dorian Finney-Smith"],["Simone Fontecchio"],["Usman Garuba"],["Paul George"],["Anthony Gill"],["Aaron Gordon"],["Jerami Grant"],["Draymond Green"],["Jeff Green"],["AJ Griffin"],["Rui Hachimura"],["Rui Hachimura"],["Tobias Harris"],["Sam Hauser"],["Gordon Hayward"],["Haywood Highsmith"],["Richaun Holmes"],["Brandon Ingram"],["Jonathan Isaac"],["Isaiah Jackson"],["LeBron James"],["Cameron Johnson"],["Cameron Johnson"],["Jalen Johnson"],["Nikola Jovic"],["Braxton Key"],["Corey Kispert"],["Maxi Kleber"],["Jonathan Kuminga"],["Kyle Kuzma"],["Jake LaRavia"],["Kawhi Leonard"],["Isaiah Livers"],["Kevon Looney"],["Trey Lyles"],["Naji Marshall"],["Caleb Martin"],["Cody Martin"],["KJ Martin"],["Jaden McDaniels"],["Jalen McDaniels"],["Jalen McDaniels"],["Doug McDermott"],["Khris Middleton"],["Justin Minaya"],["Josh Minott"],["Isaiah Mobley"],["Markieff Morris"],["Markieff Morris"],["Keegan Murray"],["Georges Niang"],["Jordan Nwora"],["Jordan Nwora"],["Royce O'Neale"],["Chuma Okeke"],["Eugene Omoruyi"],["Eugene Omoruyi"],["Cedi Osman"],["Aleksej Pokusevski"],["Bobby Portis"],["Taurean Prince"],["Paul Reed"],["Duncan Robinson"],["Jeremiah Robinson-Earl"],["David Roddy"],["Matt Ryan"],["Matt Ryan"],["Luka Samanic"],["Admiral Schofield"],["Pascal Siakam"],["Jeremy Sochan"],["Lamar Stevens"],["Cole Swider"],["Jae'Sean Tate"],["Terry Taylor"],["Terry Taylor"],["Dalen Terry"],["JT Thor"],["Xavier Tillman"],["Obi Toppin"],["Jarred Vanderbilt"],["Jarred Vanderbilt"],["Franz Wagner"],["Jabari Walker"],["Lindy Waters III"],["Trendon Watford"],["Andrew Wiggins"],["Grant Williams"],["Jaylin Williams"],["Patrick Williams"],["Ziaire Williams"],["Zion Williamson"],["Christian Wood"],["Thaddeus Young"]],"hovertemplate":"position=Forward\u003cbr\u003e2022_23_Salary=%{x}\u003cbr\u003enPER=%{y}\u003cbr\u003eFull_Name=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Forward","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Forward","orientation":"v","showlegend":true,"x":["$2,840,160","$42,492,492","$1,878,720","$4,916,160","$11,055,120","$1,563,518","$508,891","$18,352,273","$1,878,720","$2,485,200","$16,000,000","$19,550,000","$12,690,000","$2,925,600","$37,653,300","$508,891","$2,234,359","$508,891","$508,891","$4,343,919","$12,307,692","$5,121,951","$10,183,800","$508,891","$4,569,840","$44,119,845","$44,119,845","$3,359,160","$1,637,966","$1,637,966","$12,939,848","$12,939,848","$3,205,128","$2,471,160","$42,492,492","$1,836,090","$20,690,909","$20,955,000","$25,806,468","$4,500,000","$3,536,160","$6,263,188","$6,263,188","$37,633,050","$1,637,966","$30,075,000","$1,752,638","$11,215,260","$31,650,600","$17,400,000","$2,573,760","$44,474,988","$5,887,899","$5,887,899","$2,792,640","$2,239,920","$201,802","$3,552,840","$9,000,000","$5,739,840","$13, ...

# %%
avg_nPER_by_position = enhanced_merged_df.groupby('position')['nPER'].mean().reset_index()

fig = px.bar(avg_nPER_by_position, x='position', y='nPER', title='Average nPER by Position')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="43367ac0-898a-4ff1-9361-edf7e4061765" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43367ac0-898a-4ff1-9361-edf7e4061765")) {                    Plotly.newPlot(                        "43367ac0-898a-4ff1-9361-edf7e4061765",                        [{"alignmentgroup":"True","hovertemplate":"position=%{x}\u003cbr\u003enPER=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Center","Center-Forward","Forward","Forward-Center","Forward-Guard","Guard","Guard-Forward"],"xaxis":"x","y":[14.875726538488784,16.65017735520245,13.704154446324754,16.296582495358184,18.54030095250289,15.345525843300383,14.478973795724247],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5 ...

# %%
fig = px.box(enhanced_merged_df.dropna(subset=['2022_23_Salary']),
             y='2022_23_Salary', color='position',
             title='2022_23 Salary Distribution by Position')
fig.update_traces(quartilemethod="inclusive") # or "exclusive", or "linear" by default
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="724b3cd8-a690-47f4-bc14-613405e92475" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("724b3cd8-a690-47f4-bc14-613405e92475")) {                    Plotly.newPlot(                        "724b3cd8-a690-47f4-bc14-613405e92475",                        [{"alignmentgroup":"True","hovertemplate":"position=Forward\u003cbr\u003e2022_23_Salary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Forward","marker":{"color":"#636efa"},"name":"Forward","notched":false,"offsetgroup":"Forward","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y
=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Center-Forward","marker":{"color":"#00cc96"},"name":"Center-Forward","notched":false,"offsetgroup":"Center-Forwar ...

# %%
# Remove the dollar sign and commas, then convert to float
enhanced_merged_df['2022_23_Salary'] = enhanced_merged_df['2022_23_Salary'].replace('[\$,]', '', regex=True).astype(float)

# Now you can run the visualizations as provided before

fig = px.scatter(enhanced_merged_df.dropna(subset=['nPER', '2022_23_Salary']),
                 x='nPER', y='2022_23_Salary', hover_data=['Full_Name'],
                 trendline='ols', title='nPER vs. 2022_23_Salary with Trend Line')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ba0232b2-e58c-4fb8-8317-5bf3ae3850c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba0232b2-e58c-4fb8-8317-5bf3ae3850c0")) {                    Plotly.newPlot(                        "ba0232b2-e58c-4fb8-8317-5bf3ae3850c0",                        [{"customdata":[["Precious Achiuwa"],["Steven Adams"],["Bam Adebayo"],["Ochai Agbaji"],["Nickeil Alexander-Walker"],["Nickeil Alexander-Walker"],["Grayson Allen"],["Jarrett Allen"],["Jose Alvarado"],["Kyle Anderson"],["Giannis Antetokounmpo"],["Thanasis Antetokounmpo"],["Cole Anthony"],["OG Anunoby"],["Ryan Arcidiacono"],["Ryan Arcidiacono"],["Deni Avdija"],["Deandre Ayton"],["Udoka Azubuike"],["LaMelo Ball"],["Mo Bamba"],["Mo Bamba"],["Paolo Banchero"],["Desmond Bane"],["Dalano Banton"],["Dominick Barlow"],["Harrison Barnes"],["Scottie Barnes"],["RJ Barrett"],["Charles Bassey"],["Keita Bates-Diop"],["Nicolas Batum"],["Bradley Beal"],["Malik Beasley"],["Malik Beasley"],["MarJon Beauchamp"],["Davis Bertans"],["Patrick Beverley"],["Patrick Beverley"],["Saddiq Bey"],["Saddiq Bey"],["Goga Bitadze"],["Goga Bitadze"],["Bismack Biyombo"],["Bogdan Bogdanovic"],["Bojan Bogdanovic"],["Bol Bol"],["Devin Booker"],["Chris Boucher"],["James Bouknight"],["Malaki Branham"],["Christian Braun"],["Mikal Bridges"],["Mikal Bridges"],["Oshae Brissett"],["Malcolm Brogdon"],["Dillon Brooks"],["Bruce Brown"],["Jaylen Brown"],["Kendall Brown"],["Moses Brown"],["Moses Brown"],["Jalen Brunson"],["Thomas Bryant"],["Thomas Bryant"],["Alec Burks"],["Jared Butler"],["Jimmy Butler"],["Jamal Cain"],["Kentavious Caldwell-Pope"],["Vlatko Cancar"],["Clint Capela"],["Jevon Carter"],["Alex Caruso"],["Julian Champagnie"],["Julian Champagnie"],["Max Christie"],["Josh Christopher"],["Brandon Clarke"],["Jordan Clarkson"],["Amir Coffey"],["John Collins"],["Zach Collins"],["Mike Conley"],["Mike Conley"],["Pat Connaughton"],["Robert Covington"],["Torrey Craig"],["Jae Crowder"],["Cade Cunningham"],["Seth Curry"],["Stephen Curry"],["Dyson Daniels"],["Anthony Davis"],["Johnny Davis"],["JD Davison"],["DeMar DeRozan"],["Donte DiVincenzo"],["Moussa Diabate"],["Ousmane Dieng"],["Spencer Dinwiddie"],["Spencer Dinwiddie"],["Luka Doncic"],["Luguentz Dort"],["Ayo Dosunmu"],["Andre Drummond"],["Chris Duarte"],["Kris Dunn"],["Kevin Durant"],["Kevin Durant"],["Jalen Duren"],["Tari Eason"],["Anthony Edwards"],["Kessler Edwards"],["Kessler Edwards"],["Keon Ellis"],["Joel Embiid"],["Drew Eubanks"],["Bruno Fernando"],["Bruno Fernando"],["Dorian Finney-Smith"],["Dorian Finney-Smith"],["Malachi Flynn"],["Simone Fontecchio"],["Trent Forrest"],["Evan Fournier"],["De'Aaron Fox"],["Markelle Fultz"],["Daniel Gafford"],["Darius Garland"],["Usman Garuba"],["Luka Garza"],["Paul George"],["Josh Giddey"],["Shai Gilgeous-Alexander"],["Anthony Gill"],["Jacob Gilyard"],["Rudy Gobert"],["Jordan Goodwin"],["Aaron Gordon"],["Eric Gordon"],["Eric Gordon"],["Jerami Grant"],["AJ Green"],["Danny Green"],["Danny Green"],["Draymond Green"],["Jalen Green"],["Jeff Green"],["Josh Green"],["AJ Griffin"],["Quentin Grimes"],["Rui Hachimura"],["Rui Hachimura"],["Tyrese Haliburton"],["James Harden"],["Jaden Hardy"],["Gary Harris"],["Joe Harris"],["Kevon Harris"],["Tobias Harris"],["Josh Hart"],["Josh Hart"],["Isaiah Hartenstein"],["Sam Hauser"],["Jaxson Hayes"],["Killian Hayes"],["Gordon Hayward"],["Tyler Herro"],["Buddy Hield"],["Haywood Highsmith"],["Aaron Holiday"],["Jrue Holiday"],["Justin Holiday"],["Justin Holiday"],["Richaun Holmes"],["Al Horford"],["Talen Horton-Tucker"],["Caleb Houstan"],["Kevin Huerter"],["Jay Huff"],["De'Andre Hunter"],["Bones Hyland"],["Bones Hyland"],["Joe Ingles"],["Brandon Ingram"],["Kyrie Irving"],["Kyrie Irving"],["Jonathan Isaac"],["J ...

# %%
# Convert salary to float after removing dollar signs and commas
enhanced_merged_df['2022_23_Salary'] = enhanced_merged_df['2022_23_Salary'].replace('[\$,]', '', regex=True).astype(float)

# Handle NaN values in 'nPER' and '2022_23_Salary' before calculating the ratio
enhanced_merged_df = enhanced_merged_df.dropna(subset=['nPER', '2022_23_Salary'])

# Now perform the division for the 'Salary_to_nPER_Ratio'
enhanced_merged_df['Salary_to_nPER_Ratio'] = enhanced_merged_df['2022_23_Salary'] / enhanced_merged_df['nPER']

# Plotting the histogram
fig = px.histogram(enhanced_merged_df, x='Salary_to_nPER_Ratio', nbins=30, title='Histogram of Salary to nPER Ratio')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3f5d1e56-da1a-49d8-a746-fe7be2795962" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f5d1e56-da1a-49d8-a746-fe7be2795962")) {                    Plotly.newPlot(                        "3f5d1e56-da1a-49d8-a746-fe7be2795962",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Salary_to_nPER_Ratio=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[185394.14548770277,887238.2672688393,973308.7563149066,381531.6212592614,574677.0517414864,589787.8172183109,606609.5045634335,793536.8168530061,119681.48619904836,494898.8192618428,968090.3877785074,721813.4286091804,178688.34376101752,784487.5937341136,2475418.4782232977,335742.3370053227,292162.321611487,1100960.2809927934,334758.8116150654,254015.1963466847,833731.7661008486,1353867.9523165883,397256.57139789924,75506.22762581414,232063.45144999571,66012.1444922497,930686.4416322947,302805.07514894445,424965.7271813015,240220.6620997691,136810.4503003746,1796552.6313987018,1452356.5372874888,897600.0547102285,1099853.5506118473,354468.8116512014,2600248.618859837,1259814.1103589507,1034496.4610261992,147805.11868689948,176080
tyler Herro"],["Buddy Hield"],["Haywood Highsmith"],["Aaron Holiday"],["Jrue Holiday"],["Justin Holiday"],["Justin Holiday"],["Richaun Holmes"],["Al Horford"],["Talen Horton-Tucker"],["Caleb Houstan"],["Kevin Huerter"],["Jay Huff"],["De'Andre Hunter"],["Bones Hyland"],["Bones Hyland"],["Joe Ingles"],["Brandon Ingram"],["Kyrie Irving"],["Kyrie Irving"],["Jonathan Isaac"],["J ...

# %%
import plotly.express as px

# Remove non-numeric characters and convert to float for salary
enhanced_merged_df['2022_23_Salary'] = enhanced_merged_df['2022_23_Salary'].replace('[\$,]', '', regex=True).astype(float)

# Drop NaN values
enhanced_merged_df.dropna(subset=['nPER', '2022_23_Salary', 'position'], inplace=True)

# Calculate value index as nPER divided by salary (higher is better)
enhanced_merged_df['Value_Index'] = enhanced_merged_df['nPER'] / enhanced_merged_df['2022_23_Salary']

# Generate visuals for each position
for position in enhanced_merged_df['position'].unique():
    fig = px.scatter(
        enhanced_merged_df[enhanced_merged_df['position'] == position],
        x='nPER', y='2022_23_Salary',
        hover_data=['Full_Name'],
        title=f'nPER vs. 2022_23_Salary for {position} Position'
    )
    fig.show()

# Identify undervalued and overpriced players by position
for position in enhanced_merged_df['position'].unique():
    pos_df = enhanced_merged_df[enhanced_merged_df['position'] == position]

    # Top 10 undervalued players
    undervalued = pos_df.nlargest(10, 'Value_Index')

    # Top 10 overpriced players
    overpriced = pos_df.nsmallest(10, 'Value_Index')

    # Display the results
    print(f"Top 10 Undervalued Players in {position} Position:\n", undervalued[['Full_Name', 'nPER', '2022_23_Salary', 'Value_Index']])
    print(f"Top 10 Overpriced Players in {position} Position:\n", overpriced[['Full_Name', 'nPER', '2022_23_Salary', 'Value_Index']])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="95d3205d-d685-4587-b8b3-37dba07bf77f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95d3205d-d685-4587-b8b3-37dba07bf77f")) {                    Plotly.newPlot(                        "95d3205d-d685-4587-b8b3-37dba07bf77f",                        [{"customdata":[["Precious Achiuwa"],["Giannis Antetokounmpo"],["Thanasis Antetokounmpo"],["Deni Avdija"],["Paolo Banchero"],["Dalano Banton"],["Dominick Barlow"],["Harrison Barnes"],["Keita Bates-Diop"],["MarJon Beauchamp"],["Davis Bertans"],["Bojan Bogdanovic"],["Chris Boucher"],["Malaki Branham"],["Jimmy Butler"],["Jamal Cain"],["Vlatko Cancar"],["Julian Champagnie"],["Julian Champagnie"],["Brandon Clarke"],["Robert Covington"],["Torrey Craig"],["Jae Crowder"],["Moussa Diabate"],["Ousmane Dieng"],["Kevin Durant"],["Kevin Durant"],["Tari Eason"],["Kessler Edwards"],["Kessler Edwards"],["Dorian Finney-Smith"],["Dorian Finney-Smith"],["Simone Fontecchio"],["Usman Garuba"],["Paul George"],["Anthony Gill"],["Aaron Gordon"],["Jerami Grant"],["Draymond Green"],["Jeff Green"],["AJ Griffin"],["Rui Hachimura"],["Rui Hachimura"],["Tobias Harris"],["Sam Hauser"],["Gordon Hayward"],["Haywood Highsmith"],["Richaun Holmes"],["Brandon Ingram"],["Jonathan Isaac"],["Isaiah J
# 480        Daniel Theis  10.785045       8694369.0  1.240463e-06
# 380        Kelly Olynyk  19.606672      12804878.0  1.531188e-06

# %%
import plotly.express as px

# Assuming enhanced_merged_df is already prepared
# Adding trendline to the scatter plots
for position in enhanced_merged_df['position'].unique():
    position_df = enhanced_merged_df[enhanced_merged_df['position'] == position]
    fig = px.scatter(
        position_df,
        x='nPER', y='2022_23_Salary',
        hover_data=['Full_Name'],
        color='Value_Index',  # Color by Value Index
        title=f'nPER vs. 2022_23_Salary for {position} Position',
        trendline='ols'  # Ordinary Least Squares regression line
    )
    fig.update_layout(
        xaxis_title="nPER",
        yaxis_title="2022/23 Salary ($)",
        coloraxis_colorbar=dict(
            title="Value Index"
        )
    )
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9f0c6ce7-88fb-4cd5-ab6e-6b524b1133a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f0c6ce7-88fb-4cd5-ab6e-6b524b1133a4")) {                    Plotly.newPlot(                        "9f0c6ce7-88fb-4cd5-ab6e-6b524b1133a4",                        [{"customdata":[["Precious Achiuwa"],["Giannis Antetokounmpo"],["Thanasis Antetokounmpo"],["Deni Avdija"],["Paolo Banchero"],["Dalano Banton"],["Dominick Barlow"],["Harrison Barnes"],["Keita Bates-Diop"],["MarJon Beauchamp"],["Davis Bertans"],["Bojan Bogdanovic"],["Chris Boucher"],["Malaki Branham"],["Jimmy Butler"],["Jamal Cain"],["Vlatko Cancar"],["Julian Champagnie"],["Julian Champagnie"],["Brandon Clarke"],["Robert Covington"],["Torrey Craig"],["Jae Crowder"],["Moussa Diabate"],["Ousmane Dieng"],["Kevin Durant"],["Kevin Durant"],["Tari Eason"],["Kessler Edwards"],["Kessler Edwards"],["Dorian Finney-Smith"],["Dorian Finney-Smith"],["Simone Fontecchio"],["Usman Garuba"],["Paul George"],["Anthony Gill"],["Aaron Gordon"],["Jerami Grant"],["Draymond Green"],["Jeff Green"],["AJ Griffin"],["Rui Hachimura"],["Rui Hachimura"],["Tobias Harris"],["Sam Hauser"],["Gordon Hayward"],["Haywood Highsmith"],["Richaun Holmes"],["Brandon Ingram"],["Jonathan Isaac"],["Isaiah Jackson"],["LeBron James"],["Cameron Johnson"],["Cameron Johnson"],["Jalen Johnson"],["Nikola Jovic"],["Braxton Key"],["Corey Kispert"],["Maxi Kleber"],["Jonathan Kuminga"],["Kyle Kuzma"],["Jake LaRavia"],["Kawhi Leonard"],["Isaiah Livers"],["Kevon Looney"],["Trey Lyles"],["Naji Marshall"],["Caleb Martin"],["Cody Martin"],["KJ Martin"],["Jaden McDaniels"],["Jalen McDaniels"],["Jalen McDaniels"],["Doug McDermott"],["Khris Middleton"],["Justin Minaya"],["Josh Minott"],["Isaiah Mobley"],["Markieff Morris"],["Markieff Morris"],["Keegan Murray"],["Georges Niang"],["Jordan Nwora"],["Jordan Nwora"],["Royce O'Neale"],["Chuma Okeke"],["Eugene Omoruyi"],["Eugene Omoruyi"],["Cedi Osman"],["Aleksej Pokusevski"],["Bobby Portis"],["Taurean Prince"],["Paul Reed"],["Duncan Robinson"],["Jeremiah Robinson-Earl"],["David Roddy"],["Matt Ry
%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[8.230640110615796e-07,2.497413759372748e-06,1.0021007701176232e-06,6.35978211115668e-06,3.061267752152904e-06,1.7158668574333549e-06,7.590731368287856e-06,2.6311700554167413e-06,5.422300129026559e-07,4.78471034000341e-07,4.402252780935042e-06,1.6350598747214794e-05,2.0483665232356496e-06,4.125002718124366e-06,2.755177152957672e-06,2.714787536239104e-06,2.9254009511655045e-06,2.6228244401310235e-06,1.5311876872113474e-06,2.596764643147732e-06,1.6468453360431792e-06,9.545524075467595e-07,1.003512571367172e-06,1.562550172794877e-06,1.6735898749496525e-06,1.11530618398285e-06,1.1113158274017198e-06,3.1799904498028496e-06,5.651558723107075e-06,1.2404631872049682e-06,4.583513079455714e-06,8.173631552048815e-06,1.4588390064142107e-05],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[19.34200425994712,18.355991131389697,38.06050876162181,12.517164156625798,8.318661438290532,4.6626811555876815,14.655280828857366,4.8310650270501245,16.568905152906044,14.620624074875334,4.913407155834971,18.249099468951396,33.74776842870887,7.8823026939551255,9.643120035351853,9.501756376836864,7.658114609961058,16.773381946548316,19.606671529843464,23.5797058106376,14.954042385777196,32.295753425492535,11.119044729819688,37.12619210560628,35.31274636143767,10.305429140001534,10.26855824519189,14.851064199051276,19.403609595217983,10.785044680476073,8.849301615756637,15.355965069465148,10.852624313296724],"xaxis":"x","y":[23500000.0,7350000.0,37980720.0,1968175.0,2717391.0,2717391.0,1930681.0,1836090.0,30556968.0,30556968.0,1116112.0,1116112.0,16475454.0,1910860.0,3500000.0,3500000.0,2617800.0,6395160.0,12804878.0,9080417.0,9080417.0,33833400.0,11080125.0,23760000.0,21100000.0,9240000.0,9240000.0,4670160.0,3433320.0,8694369.0,1930681.0,1878720.0,743922.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003e2022_23_Salary = 808850 * nPER + -2.86037e+06\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.502601\u003cbr\u003e\u003cbr\u003enPER=%{x}\u003cbr\u003e2022_23_Salary=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[4.6626811555876815,4.8310650270501245,4.913407155834971,7.658114609961058,7.8823026939551255,8.318661438290532,8.849301615756637,9.501756376836864,9.643120035351853,10.26855824519189,10.305429140001534,10.785044680476073,10.852624313296724,11.119044729819688,12.517164156625798,14.620624074875334,14.655280828857366,14.85106 ...

# %%
import pandas as pd

# Assuming enhanced_merged_df is your DataFrame
null_count = enhanced_merged_df['2022_23_Salary'].isnull().sum()
print("Number of null or NaN values in 2022_23_Salary:", null_count)
# Out:
# Number of null or NaN values in 2022_23_Salary: 0

# %%
enhanced_merged_df.columns
# Out:
# Index(['PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS', 'TEAM_NAME', 'id', 'Full_Name', 'position',
#        'PACE', 'uPER', 'aPER', 'nPER', '2022_23_Salary',
#        'Adjusted_Salary_2022_23', 'Salary_to_nPER_Ratio', 'Value_Index'],
#       dtype='object')

# %%
from nba_api.stats.endpoints import leaguedashplayerstats

def fetch_league_averages(season):
    player_stats = leaguedashplayerstats.LeagueDashPlayerStats(season=season, measure_type_detailed_defense='Base')
    player_data = player_stats.get_data_frames()[0]

    lgAST = player_data['AST'].sum() / player_data['GP'].sum()
    lgFG = player_data['FGM'].sum()
    lgPTS = player_data['PTS'].sum()
    lgFT = player_data['FTM'].sum()
    lgOREB = player_data['OREB'].sum()
    lgTOV = player_data['TOV'].sum()
    lgFTA = player_data['FTA'].sum()
    lgTRB = player_data['REB'].sum()

    return lgAST, lgFG, lgPTS, lgFT, lgOREB, lgTOV, lgFTA, lgTRB

#  usage
season = '2022-23'  # specify the season
lgAST, lgFG, lgPTS, lgFT, lgOREB, lgTOV, lgFTA, lgTRB = fetch_league_averages(season)

def calculate_uPER(row):
    factor = (2 / 3) - (0.5 * (lgAST / lgFG)) / (2 * (lgFG / lgFT))
    VOP = lgPTS / (lgFG - lgOREB + lgTOV + 0.44 * lgFTA)
    DRB_perc = (lgTRB - lgOREB) / lgTRB

    uPER = (1 / row['MIN']) * (
        row['FGM'] * VOP
        + 0.44 * row['FTA'] * VOP
        - row['FTA']
        + VOP * (row['REB'] - row['OREB'])
        + row['AST'] * VOP * factor
        + row['STL'] * VOP * DRB_perc
        - row['PF'] * ((row['FGA'] - row['FGM']) * (1 - DRB_perc) + row['FTA'] * 0.4 * (1 - DRB_perc))
        - row['TOV']
    )
    return uPER

def calculate_aPER(uPER, team_pace, league_pace):
    aPER = uPER * (league_pace / team_pace)
    return aPER

def calculate_nPER(aPER, league_average_aPER):
    nPER = aPER * (15 / league_average_aPER)
    return nPER

# %%
# Calculate the updated uPER for each row
enhanced_merged_df['uPER'] = enhanced_merged_df.apply(calculate_uPER, axis=1)

# Calculate league average aPER
league_average_aPER = enhanced_merged_df['uPER'].mean()

# Calculate the updated aPER and nPER for each row
enhanced_merged_df['aPER'] = enhanced_merged_df.apply(lambda row: calculate_aPER(row['uPER'], row['PACE'], league_pace), axis=1)
enhanced_merged_df['nPER'] = enhanced_merged_df.apply(lambda row: calculate_nPER(row['aPER'], league_average_aPER), axis=1)

# %%
import plotly.express as px

# Ensure that the '2022_23_Salary' column is in the correct numeric format
enhanced_merged_df['2022_23_Salary'] = enhanced_merged_df['2022_23_Salary'].replace('[\$,]', '', regex=True).astype(float)

# Create the box plot
fig = px.box(enhanced_merged_df, x='position', y=['2022_23_Salary', 'nPER'],
             title='Box Plot of Salary and nPER by Position',
             labels={'value':'Metric', 'variable':'Metric Type'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="04109532-aff9-4388-a1a2-0c60c7be723d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04109532-aff9-4388-a1a2-0c60c7be723d")) {                    Plotly.newPlot(                        "04109532-aff9-4388-a1a2-0c60c7be723d",                        [{"alignmentgroup":"True","hovertemplate":"position=%{x}\u003cbr\u003eMetric=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Forward","Center","Center-Forward","Guard","Guard","Guard","Guard","Center","Guard","Forward-Guard","Forward","Forward","Guard","Forward-Guard","Guard","Guard","Forward","Center","Center-Forward","Guard","Center","Center","Forward","Guard","Forward","Forward","Forward","Forward-Guard","Forward-Guard","Center-Forward","Forward","Guard-Forward","Guard","Guard","Guard","Forward","Forward","Guard","Guard","Guard-Forward","Guard-Forward","Center-Forward","Center-Forward","Center","Guard","Forward","Center-Forward","Guard","Forward","Guard","Forward","Guard","Guard-Forward","Guard-Forward","Forward-Guard","Guard","Guard-Forward","Guard-Forward","Guard-Forward","Guard","Center","Center","Guard","Center-Forward","Center-Forward","Guard","Guard","Forward","Forward","Guard","Forward","Center","Guard","Guard","Forward","Forward","Guard","Guard","Forward","Guard","Guard-Forward","Forward-Center","Forward-Center","Guard","Guard","Guard","Forward","Forward","Forward","Guard","Guard","Guard","Guard","Forward-Center","Guard","Guard","Guard-Forward","Guard","Forward","Forward","Guard","Guard","Forward-Guard","Guard","Guard","Center","Guard","Guard","Forward","Forward","Center","Forward","Guard","Forward","Forward","Guard","Center-Forward","Forward-Center","Forward-Center","Forward-Center","Forward","Forward","Guard","Forward","Guard","Guard-Forward","Guard","Guard","Forward-Center","Guard","Forward","Center","Forward","Guard","Guard","Forward","Guard","Center","Guard","Forward","Guard","Guard","Forward","Guard","Guard","Guard","Forward","Guard","Forward","Guard","Forward","Guard","Forward","Forward","Guard","Guard","Guard","Guard","Guard-Forward","Guard","Forward","Guard","Guard","Center-Forward","Forward","Center-Forward","Guard","Forward","Guard","Guard","Forward","Guard","Guard","Forward-Guard","Forward-Guard","Forward","Center-Forward","Guard","Guard","Guard-Forward","Center","Forward-Guard","Guard","Guard","Forward-Guard","Forward","Guard","Guard","Forward","Guard","Forward","Guard","Guard","Forward","Guard-Forward","Guard","Forward","Forward","Forward","Forward-Guard","Guard","Center","Center","Center","Guard","Guard","Center","Guard","Forward","Guard","Guard","Guard","Center","Forward","Forward","Forward","Forward-Center","Center","Guard","Guard-Forward","Center-Forward","Forward","Forward","Forward","Guard","Center","Guard","Guard-Forward","Guard","Guard","Center","Forward","Guard","Forward-Guard","Forward","Forward","Center","Center","Forward-Center","Forward-Center","Guard","Forward","Guard","Forward-Center","Forward-Center","Guard-Forward","Guard","Center","Forward-Center","Forward","Forward","Forward","Forward","Guard","Guard","Guard-Forward","Guard","Guard","Guard","Guard","Guard","Forward","Forward","Forward","Forward","Center-Forward","Guard","Guard","Guard","Guard","Forward-Center","Forward","Guard-Forward","Forward","Forward","Guard","Guard","Center","Forward","Guard","Guard","Guard","Forward","Forward","Guard","Guard","Guard","Forward","Forward-Center","Forward-Center","Guard-Forward","Guard-Forward","Forward","Guard","Forward-Center","Guard","Center","Forward","Forward","Forward","Forward","Guard","Forward-Center","Forward ...

# %%
import plotly.express as px

# Assuming 'enhanced_merged_df' is already loaded and contains the columns '2022_23_Salary', 'nPER', and 'position'

# We need to ensure that salary data is in a numeric format without any non-numeric characters
enhanced_merged_df['2022_23_Salary'] = enhanced_merged_df['2022_23_Salary'].replace('[\$,]', '', regex=True).astype(float)

# Now let's create the scatter plot
fig = px.scatter(
    enhanced_merged_df,
    x='2022_23_Salary',
    y='nPER',
    color='position',  # Differentiates data points by position
    hover_data=['Full_Name'],  # Shows player name when you hover over points
    title='Scatter Plot of Salary and nPER by Position'
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee517306-519a-4418-a056-360cf9fcb578" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Forward","orientation":"v","showlegend":true,"x":[2840160.0,42492492.0,1878720.0,4916160.0,11055120.0,1563518.0,508891.0,18352273.0,1878720.0,2485200.0,16000000.0,19550000.0,12690000.0,2925600.0,37653300.0,508891.0,2234359.0,508891.0,508891.0,4343919.0,12307692.0,5121951.0,10183800.0,508891.0,4569840.0,44119845.0,44119845.0,3359160.0,1637966.0,1637966.0,12939848.0,12939848.0,3205128.0,2471160.0,42492492.0,1836090.0,20690909.0,20955000.0,25806468.0,4500000.0,3536160.0,6263188.0,6263188.0,37633050.0,1637966.0,30075000.0,1752638.0,11215260.0,31650600.0,17400000.0,2573760.0,44474988.0,5887899.0,5887899.0,2792640.0,2239920.0,201802.0,3552840.0,9000000.0,5739840.0,13000000.0,3047640.0,42492492.0,1563518.0,8000000.0,2625000.0,1782621.0,6479000.0,7000000.0,1782621.0,2161440.0,1930681.0,1930681.0,13750000.0,37984276.0,35096.0,1017781.0,508891. ...

# %%
enhanced_merged_df.to_csv("enhanced_merged_df.csv")

# %%
enhanced_merged_df.head()
# Out:
#   PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  GP  \
# 0   1630173   2022-23        00  1610612761               TOR        23.0  55
# 1    203500   2022-23        00  1610612763               MEM        29.0  42
# 2   1628389   2022-23        00  1610612748               MIA        25.0  75
# 3   1630534   2022-23        00  1610612762               UTA        23.0  59
# 5   1629638   2022-23        00  1610612762               UTA        24.0  36
#
#    GS     MIN  FGM  ...                 Full_Name        position    PACE  \
# 0  12  1141.0  196  ...          Precious Achiuwa         Forward   97.85
# 1  42  1133.0  157  ...              Steven Adams          Center  101.50
# 2  75  2598.0  602  ...               Bam Adebayo  Center-Forward   96.76
# 3  22  1209.0  165  ...              Ochai Agbaji           Guard  101.02
# 5   3   528.0   83  ...  Nickeil Alexander-Walker           Guard  101.02
#
#         uPER       aPER       nPER 2022_23_Salary  Adjusted_Salary_2022_23  \
# 0  -4.719290  -4.812936  16.424833      2840160.0               $2,924,489
# 1  -2.402841  -2.362399   8.062026     17926829.0              $18,459,108
# 2 -11.961304 -12.336074  42.098618     30351780.0              $31,252,978
# 3  -4.414841  -4.361160  14.883082      3918360.0               $4,034,703
# 5  -2.002438  -1.978090   6.750516      5009633.0               $5,158,377
#
#   Salary_to_nPER_Ratio Value_Index
# 0        185394.145488    0.000005
# 1        887238.267269    0.000001
# 2        973308.756315    0.000001
# 3        381531.621259    0.000003
# 5        574677.051741    0.000002
#
# [5 rows x 39 columns]

# %%
import pandas as pd
import plotly.express as px

# Load the enhanced merged dataframe
# enhanced_merged_df = pd.read_csv('/mnt/data/enhanced_merged_df.csv')

# We only want to consider players who have a salary and nPER listed
enhanced_merged_df.dropna(subset=['2022_23_Salary', 'nPER'], inplace=True)

# Scatter plot with nPER vs Salary and colored by position
scatter_fig = px.scatter(enhanced_merged_df,
                         x='nPER',
                         y='2022_23_Salary',
                         color='position',
                         hover_data=['Full_Name'],
                         title='nPER vs. Salary by Position')

# Box plot for nPER by position to get a sense of distribution
box_fig = px.box(enhanced_merged_df,
                 y='nPER',
                 x='position',
                 color='position',
                 title='Box Plot of nPER by Position')

# Calculate a simple metric for value: salary divided by nPER
# The lower the number, the more 'value' a player might be providing per their performance
enhanced_merged_df['Value_Metric'] = enhanced_merged_df['2022_23_Salary'] / enhanced_merged_df['nPER']

# Sorting the dataframe by the value metric to find the top 10 overvalued and undervalued players
overvalued_players = enhanced_merged_df.sort_values(by='Value_Metric', ascending=False).head(10)
undervalued_players = enhanced_merged_df.sort_values(by='Value_Metric', ascending=True).head(10)

scatter_fig.show()
box_fig.show()

overvalued_players[['Full_Name', 'position', 'nPER', '2022_23_Salary', 'Value_Metric']]
undervalued_players[['Full_Name', 'position', 'nPER', '2022_23_Salary', 'Value_Metric']]

overvalued_players.head()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bc641481-0ef3-4d3a-8b48-2656f55b2fc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc641481-0ef3-4d3a-8b48-2656f55b2fc5")) {                    Plotly.newPlot(                        "bc641481-0ef3-4d3a-8b48-2656f55b2fc5",                        [{"customdata":[["Precious Achiuwa"],["Giannis Antetokounmpo"],["Thanasis Antetokounmpo"],["Deni Avdija"],["Paolo Banchero"],["Dalano Banton"],["Dominick Barlow"],["Harrison Barnes"],["Keita Bates-Diop"],["MarJon Beauchamp"],["Davis Bertans"],["Bojan Bogdanovic"],["Chris Boucher"],["Malaki Branham"],["Jimmy Butler"],["Jamal Cain"],["Vlatko Cancar"],["Julian Champagnie"],["Julian Champagnie"],["Brandon Clarke"],["Robert Covington"],["Torrey Craig"],["Jae Crowder"],["Moussa Diabate"],["Ousmane Dieng"],["Kevin Durant"],["Kevin Durant"],["Tari Eason"],["Kessler Edwards"],["Kessler Edwards"],["Dorian Finney-Smith"],["Dorian Finney-Smith"],["Simone Fontecchio"],["Usman Garuba"],["Paul George"],["Anthony Gill"],["Aaron Gordon"],["Jerami Grant"],["Draymond Green"],["Jeff Green"],["AJ Griffin"],["Rui Hachimura"],["Rui Hachimura"],["Tobias Harris"],["Sam Hauser"],["Gordon Hayward"],["Haywood Highsmith"],["Richaun Holmes"],["Brandon Ingram"],["Jonathan Isaac"],["Isaiah Jackson"],["LeBron James"],["Cameron Johnson"],["Cameron Johnson"],["Jalen Johnson"],["Nikola Jovic"],["Braxton Key"],["Corey Kispert"],["Maxi Kleber"],["Jonathan Kuminga"],["Kyle Kuzma"],["Jake LaRavia"],["Kawhi Leonard"],["Isaiah Livers"],["Kevon Looney"],["Trey Lyles"],["Naji Marshall"],["Caleb Martin"],["Cody Martin"],["KJ Martin"],["Jaden McDaniels"],["Jalen McDaniels"],["Jalen McDaniels"],["Doug McDermott"],["Khris Middleton"],["Justin Minaya"],["Josh Minott"],["Isaiah Mobley"],["Markieff Morris"],["Markieff Morris"],["Keegan Murray"],["Georges Niang"],["Jordan Nwora"],["Jordan Nwora"],["Royce O'Neale"],["Chuma Okeke"],["Eugene Omoruyi"],["Eugene Omoruyi"],["Cedi Osman"],["Aleksej Pokusevski"],["Bobby Portis"],["Taurean Prince"],["Paul Reed"],["Duncan Robinson"],["Jeremiah Robinson-Earl"],["David Roddy"],["Matt Ryan"],["Matt Ryan"],["Luka Samanic"],["Admiral Schofield"],["Pascal Siakam"],["Jeremy Sochan"],["Lamar Stevens"],["Cole Swider"],["Jae'Sean Tate"],["Terry Taylor"],["Terry Taylor"],["Dal
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 26    1628964   2022-23        00  1610612747               LAL        25.0
# 478    202066   2022-23        00  1610612740               NOP        37.0
# 435   1626156   2022-23        00  1610612747               LAL        27.0
# 110    203109   2022-23        00  1610612749               MIL        32.0
# 298    201567   2022-23        00  1610612748               MIA        34.0
#
#      GP  GS    MIN  FGM  ...        position    PACE      uPER      aPER  \
# 26    9   1   88.0   11  ...          Center  101.92 -0.113408 -0.111040
# 478  25   0  162.0   18  ...   Guard-Forward   99.58 -0.080705 -0.080877
# 435  17  17  526.0  107  ...           Guard  101.92 -0.593919 -0.581516
# 110  18   3  340.0   45  ...         Forward  101.45 -0.293235 -0.288442
# 298  21  17  419.0   54  ...  Forward-Center   96.76 -0.888070 -0.915895
#
#          nPER 2022_23_Salary Adjusted_Salary_2022_23  Salary_to_nPER_Ratio  \
# 26   0.378939     10300000.0             $10,605,825          1.353868e+06
# 478  0.276004      5155500.0              $5,308,575          1.693965e+06
# 435  1.984507     31377750.0             $32,309,411          1.330091e+06
# 110  0.984350     10183800.0             $10,486,175          8.757699e+05
# 298  3.125622     30556968.0             $31,464,258          2.089991e+06
#
#       Value_Index  Value_Metric
# 26   7.386245e-07  2.718112e+07
# 478  5.903308e-07  1.867909e+07
# 435  7.518280e-07  1.581136e+07
# 110  1.141852e-06  1.034571e+07
# 298  4.784710e-07  9.776283e+06
#
# [5 rows x 40 columns]

# %%
overvalued_players["Full_Name"].head(10)
# Out:
# 26              Mo Bamba
# 478       Garrett Temple
# 435     D'Angelo Russell
# 110          Jae Crowder
# 298           Kevin Love
# 467       Jaden Springer
# 517    Russell Westbrook
# 287             Alex Len
# 51          Goga Bitadze
# 431         Derrick Rose
# Name: Full_Name, dtype: object

# %%
undervalued_players["Full_Name"].head(10)
# Out:
# 514     Peyton Watson
# 312       Cody Martin
# 175       Danny Green
# 445      Olivier Sarr
# 388    Gary Payton II
# 132      Kevin Durant
# 249      Damian Jones
# 176       Danny Green
# 248      Damian Jones
# 480      Daniel Theis
# Name: Full_Name, dtype: object

# %%
import pandas as pd

# Load your dataframe
# enhanced_merged_df = pd.read_csv('/mnt/data/enhanced_merged_df.csv')

# Assuming '2022_23_Salary' is already converted to float and 'nPER' is calculated correctly
# Create a value score by dividing nPER by salary
enhanced_merged_df['Value_Score'] = enhanced_merged_df['nPER'] / enhanced_merged_df['2022_23_Salary']

# Now, sort the dataframe by 'Value_Score' and 'position' to find the top 10 undervalued and overvalued players
undervalued = enhanced_merged_df.sort_values(by=['position', 'Value_Score'], ascending=[True, False])
overvalued = enhanced_merged_df.sort_values(by=['position', 'Value_Score'], ascending=[True, True])

top_undervalued_by_position = undervalued.groupby('position').head(10)
top_overvalued_by_position = overvalued.groupby('position').head(10)

# Display results
print("Top Undervalued Players by Position:")
print(top_undervalued_by_position[['Full_Name', 'position', 'nPER', '2022_23_Salary', 'Value_Score']])

print("\nTop Overvalued Players by Position:")
print(top_overvalued_by_position[['Full_Name', 'position', 'nPER', '2022_23_Salary', 'Value_Score']])
# Out:
# Top Undervalued Players by Position:
#               Full_Name       position       nPER  2022_23_Salary  Value_Score
# 158          Luka Garza         Center   7.707382        508891.0     0.000015
# 449      Alperen Sengun         Center  42.700625       3375360.0     0.000013
# 278        Jock Landale         Center  18.760273       1563518.0     0.000012
# 421       Nick Richards         Center  16.638558       1782621.0     0.000009
# 427    Orlando Robinson         Center   3.302110        386055.0     0.000009
# ..                  ...            ...        ...             ...          ...
# 283          Damion Lee  Guard-Forward  16.989174       2133278.0     0.000008
# 525      Jalen Williams  Guard-Forward  28.170383       4341480.0     0.000006
# 47           Saddiq Bey  Guard-Forward  18.582525       2959080.0     0.000006
# 317  Bennedict Mathurin  Guard-Forward  40.130873       6586800.0     0.000006
# 527    Kenrich Williams  Guard-Forward  11.138748       2000000.0     0.000006
#
# [70 rows x 5 columns]
#
# Top Overvalued Players by Position:
#             Full_Name       position       nPER  2022_23_Salary   Value_Score
# 403      Micah Potter         Center  -3.032437        508891.0 -5.958913e-06
# 221          Jay Huff         Center  -0.550736        116986.0 -4.707708e-06
# 410     Neemias Queta         Center  -2.173512        508891.0 -4.271075e-06
# 308  Boban Marjanovic         Center  -2.002016       4101478.0 -4.881207e-07
# 73        Moses Brown         Center  -0.330428        824041.0 -4.009847e-07
# ..                ...            ...        ...             ...           ...
# 64      Mikal Bridges  Guard-Forward  10.357990      20100000.0  5.153229e-07
# 37      Nicolas Batum  Guard-Forward  15.265368      19700319.0  7.748792e-07
# 485  Matisse Thybulle  Guard-Forward   3.578806       4379526.0  8.171675e-07
# 196        Joe Harris  Guard-Forward  17.060411      18642857.0  9.151178e-07
# 63      Mikal Bridges  Guard-Forward  20.000165      20100000.0  9.950331e-07
#
# [70 rows x 5 columns]

# %%
import pandas as pd

# Load the merged dataframe containing all the enhanced player data including nPER and salary

# Filter the dataframe for players from the Miami Heat
miami_heat_players = enhanced_merged_df[enhanced_merged_df['TEAM_ABBREVIATION'] == 'MIA']

# Perform a descriptive analysis on the Miami Heat players
miami_heat_analysis = {
    'Total Players': miami_heat_players.shape[0],
    'Average Age': miami_heat_players['PLAYER_AGE'].mean(),
    'Average nPER': miami_heat_players['nPER'].mean(),
    'Total Salary': miami_heat_players['2022_23_Salary'].sum(),
    'Average Salary': miami_heat_players['2022_23_Salary'].mean(),
    'Highest Paid Player': miami_heat_players.loc[miami_heat_players['2022_23_Salary'].idxmax(), 'Full_Name'],
    'Top Performer by nPER': miami_heat_players.loc[miami_heat_players['nPER'].idxmax(), 'Full_Name'],
    'Salary of Top Performer by nPER': miami_heat_players.loc[miami_heat_players['nPER'].idxmax(), '2022_23_Salary'],
    'nPER of Highest Paid Player': miami_heat_players.loc[miami_heat_players['2022_23_Salary'].idxmax(), 'nPER'],
}

# Display the analysis
miami_heat_analysis
# Out:
# {'Total Players': 17,
#  'Average Age': 27.352941176470587,
#  'Average nPER': 13.158505155658789,
#  'Total Salary': 176138273.0,
#  'Average Salary': 10361074.88235294,
#  'Highest Paid Player': 'Jimmy Butler',
#  'Top Performer by nPER': 'Bam Adebayo',
#  'Salary of Top Performer by nPER': 30351780.0,
#  'nPER of Highest Paid Player': 16.698386466429064}

# %%
# Assuming df['2022_23_Salary'] has already been cleaned and converted to float earlier in the script
# Calculate the Value Ratio for each player
miami_heat_df['Value_Ratio'] = miami_heat_df['nPER'] / miami_heat_df['2022_23_Salary']

# Now we can proceed to find the top 3 players by value for each position
top_players_by_position = {}
for position in miami_heat_df['position'].unique():
    top_players = miami_heat_df[miami_heat_df['position'] == position] \
        .sort_values(by='Value_Ratio', ascending=False) \
        .head(3)
    top_players_by_position[position] = top_players

top_players_by_position
import plotly.express as px

# Loop through each position and create a bar chart for the top 3 players by value
for position, players in top_players_by_position.items():
    fig = px.bar(players,
                 x='Full_Name',
                 y='Value_Ratio',
                 title=f'Top 3 Valued Players in Position: {position}')
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e9043872-c45d-41f7-8d14-f29e70710e43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9043872-c45d-41f7-8d14-f29e70710e43")) {                    Plotly.newPlot(                        "e9043872-c45d-41f7-8d14-f29e70710e43",                        [{"alignmentgroup":"True","hovertemplate":"Full_Name=%{x}\u003cbr\u003eValue_Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bam Adebayo"],"xaxis":"x","y":[1.3870230368585242e-06],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="90682608-6e49-4b00-a86d-68c9814ef34e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90682608-6e49-4b00-a86d-68c9814ef34e")) {                    Plotly.newPlot(                        "90682608-6e49-4b00-a86d-68c9814ef34e",                        [{"alignmentgroup":"True","hovertemplate":"Full_Name=%{x}\u003cbr\u003eValue_Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Haywood Highsmith","Caleb Martin","Nikola Jovic"],"xaxis":"x","y":[4.373598129996757e-06,2.763683065700893e-06,8.086861348660036e-07],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scatte ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8c857217-e504-4beb-8a13-5a82da20f8c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c857217-e504-4beb-8a13-5a82da20f8c6")) {                    Plotly.newPlot(                        "8c857217-e504-4beb-8a13-5a82da20f8c6",                        [{"alignmentgroup":"True","hovertemplate":"Full_Name=%{x}\u003cbr\u003eValue_Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Gabe Vincent","Tyler Herro","Victor Oladipo"],"xaxis":"x","y":[1.4048352272269765e-05,3.915409689304709e-06,2.0980537822642744e-06],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scatterg ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e9af5d89-1713-415e-8feb-eb099c1d66b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9af5d89-1713-415e-8feb-eb099c1d66b8")) {                    Plotly.newPlot(                        "e9af5d89-1713-415e-8feb-eb099c1d66b8",                        [{"alignmentgroup":"True","hovertemplate":"Full_Name=%{x}\u003cbr\u003eValue_Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Cody Zeller","Kevin Love"],"xaxis":"x","y":[2.7549717350028998e-06,1.0228836947046344e-07],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colo ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="92e350e8-bc75-497f-ab0e-a244a5d03cdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92e350e8-bc75-497f-ab0e-a244a5d03cdb")) {                    Plotly.newPlot(                        "92e350e8-bc75-497f-ab0e-a244a5d03cdb",                        [{"alignmentgroup":"True","hovertemplate":"Full_Name=%{x}\u003cbr\u003eValue_Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Orlando Robinson","Omer Yurtseven"],"xaxis":"x","y":[8.553470271840291e-06,-3.422615083254973e-07],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4e5ac25d-f970-4cf5-b22b-1dfb201f7285" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e5ac25d-f970-4cf5-b22b-1dfb201f7285")) {                    Plotly.newPlot(                        "4e5ac25d-f970-4cf5-b22b-1dfb201f7285",                        [{"alignmentgroup":"True","hovertemplate":"Full_Name=%{x}\u003cbr\u003eValue_Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Max Strus"],"xaxis":"x","y":[1.593065335915879e-05],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}], ...

# %%
# Create a value ratio for the entire league
df['Value_Ratio'] = df['nPER'] / df['2022_23_Salary']

# Get top 3 players by value ratio for each position in the league
top_players_league_by_position = {}
bottom_players_heat_by_position = {}

for position in df['position'].unique():
    top_players_league_by_position[position] = df[df['position'] == position].sort_values(by='Value_Ratio', ascending=False).head(3)
    bottom_players_heat_by_position[position] = miami_heat_df[miami_heat_df['position'] == position].sort_values(by='Value_Ratio', ascending=True).head(3)

# Code for visualization would be similar to the previous example but would include both top_players_league_by_position and bottom_players_heat_by_position

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Assuming top_players_league_by_position and bottom_players_heat_by_position are dictionaries
# with position as keys and top 3 players dataframes as values

# Create subplots
fig = make_subplots(rows=2, cols=1, subplot_titles=("Top 3 Players by Position in the League", "Bottom 3 Players by Position on Miami Heat"))

# Add traces for top 3 in the league
for idx, position in enumerate(top_players_league_by_position.keys()):
    fig.add_trace(
        go.Bar(x=top_players_league_by_position[position]['Full_Name'],
               y=top_players_league_by_position[position]['Value_Ratio'],
               name=f"Top {position}"),
        row=1, col=1
    )

# Add traces for bottom 3 on the Heat
for idx, position in enumerate(bottom_players_heat_by_position.keys()):
    fig.add_trace(
        go.Bar(x=bottom_players_heat_by_position[position]['Full_Name'],
               y=bottom_players_heat_by_position[position]['Value_Ratio'],
               name=f"Bottom {position}"),
        row=2, col=1
    )

# Update layout
fig.update_layout(height=1200, width=800, title_text="Value Ratio by Position")

# Show figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eb83ff4d-790d-4637-8de0-0c2bf02b78eb" class="plotly-graph-div" style="height:1200px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb83ff4d-790d-4637-8de0-0c2bf02b78eb")) {                    Plotly.newPlot(                        "eb83ff4d-790d-4637-8de0-0c2bf02b78eb",                        [{"name":"Top Forward","x":["Jaden McDaniels","Jalen McDaniels","KJ Martin"],"y":[1.602337027473136e-05,1.2619251558453207e-05,1.0389609626765708e-05],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Top Center","x":["Luka Garza","Alperen Sengun","Jock Landale"],"y":[1.5145447356920088e-05,1.265068767294479e-05,1.1998757589130438e-05],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Top Center-Forward","x":["Naz Reid","Bol Bol","Thomas Bryant"],"y":[1.691832988467334e-05,4.63567317970321e-06,3.585737453279356e-06],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Top Guard","x":["Desmond Bane","Jordan Poole","Immanuel Quickley"],"y":[1.611155952720144e-05,1.5271693894076085e-05,1.4588620579974844e-05],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Top Forward-Guard","x":["Keldon Johnson","Oshae Brissett","RJ Barrett"],"y":[8.558419864171263e-06,6.9927711906248165e-06,4.331369173575802e-06],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Top Guard-Forward","x":["Max Strus","Andrew Nembhard","Aaron Nesmith"],"y":[1.593065335915879e-05,1.0914307595530733e-05,1.0269711143722178e-05],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Top Forward-Center","x":["Moritz Wagner","Daniel Gafford","Drew Eubanks"],"y":[1.3042277309767173e-05,7.647845373819905e-06,6.3147951309882266e-06],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Bottom Forward","x":["Jamal Cain","Jimmy Butler","Duncan Robinson"],"y":[3.2588232936453845e-07,4.4347737028173e-07,7.93415931188247e-07],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Bottom Center","x":["Omer Yurtseven","Orlando Robinson"],"y":[-3.422615083254973e-07,8.553470271840291e-06],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Bottom Center-Forward","x":["Bam Adebayo"],"y":[1.3870230368585242e-06],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Bottom Guard","x":["Dru Smith","Kyle Lowry","Victor Oladipo"],"y":[-2.46111474819301e-06,7.689948840029602e-07,2.0980537822642744e-06],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Bottom Forward-Guard","x":[],"y":[],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Bottom Guard-Forward","x":["Max Strus"],"y":[1.593065335915879e-05],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Bottom Forward-Center","x":["Kevin Love","Cody Zeller"],"y":[1.0228836947046344e-07,2.7549717350028998e-06],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3 ...

# %%
df = enhanced_merged_df

# Add a column for value ratio
df['Value_Ratio'] = df['nPER'] / df['2022_23_Salary']

# League-Wide Analysis
top_3_league = df.groupby('position').apply(lambda x: x.nlargest(3, 'Value_Ratio')).reset_index(drop=True)
bottom_3_league = df.groupby('position').apply(lambda x: x.nsmallest(3, 'Value_Ratio')).reset_index(drop=True)

# Miami Heat Analysis
miami_heat_df = df[df['TEAM_ABBREVIATION'] == 'MIA']
top_3_heat = miami_heat_df.groupby('position').apply(lambda x: x.nlargest(3, 'Value_Ratio')).reset_index(drop=True)
bottom_3_heat = miami_heat_df.groupby('position').apply(lambda x: x.nsmallest(3, 'Value_Ratio')).reset_index(drop=True)

# %%
# Assuming 'enhanced_merged_df' is your DataFrame with nPER and salary data
# Make sure the '2022_23_Salary' column is in float format
enhanced_merged_df['2022_23_Salary'] = enhanced_merged_df['2022_23_Salary'].replace('[\$,]', '', regex=True).astype(float)

# Calculate the Value Ratio
enhanced_merged_df['Value_Ratio'] = enhanced_merged_df['nPER'] / enhanced_merged_df['2022_23_Salary']

# Sort by Value Ratio in ascending order to find the most overvalued players
overvalued_players = enhanced_merged_df.sort_values(by='Value_Ratio').head(15)

# Print the top 5 overvalued players
print(overvalued_players[['Full_Name', 'nPER', '2022_23_Salary', 'Value_Ratio']])
# Out:
#              Full_Name      nPER  2022_23_Salary  Value_Ratio
# 163      Jacob Gilyard -1.744888          5849.0    -0.000298
# 493      Stanley Umude -2.385368         58493.0    -0.000041
# 320        Skylar Mays -1.262593        116574.0    -0.000011
# 412    Lester Quinones -1.310632        129405.0    -0.000010
# 338      Justin Minaya -0.328495         35096.0    -0.000009
# 523  Lindell Wigginton -0.786289         99438.0    -0.000008
# 263        Braxton Key -1.504061        201802.0    -0.000007
# 403       Micah Potter -3.032437        508891.0    -0.000006
# 221           Jay Huff -0.550736        116986.0    -0.000005
# 410      Neemias Queta -2.173512        508891.0    -0.000004
# 472        Cole Swider -1.618577        508891.0    -0.000003
# 117         JD Davison -1.618352        508891.0    -0.000003
# 343      Isaiah Mobley -1.402983        508891.0    -0.000003
# 71       Kendall Brown -1.393159        508891.0    -0.000003
# 460          Dru Smith -1.000353        374357.0    -0.000003

# %%
# Filter players who have played more than 41 games
players_over_41_games = enhanced_merged_df[enhanced_merged_df['GP'] > 41]

# Sort by Value Ratio in ascending order for overvalued players
overvalued_players = players_over_41_games.sort_values(by='Value_Ratio').head(15)

# Sort by Value Ratio in descending order for undervalued players
undervalued_players = players_over_41_games.sort_values(by='Value_Ratio', ascending=False).head(15)

# Print the top 15 overvalued and undervalued players
print("Top 15 Overvalued Players:")
print(overvalued_players[['Full_Name', 'nPER', '2022_23_Salary', 'Value_Ratio']])
print("\nTop 15 Undervalued Players:")
print(undervalued_players[['Full_Name', 'nPER', '2022_23_Salary', 'Value_Ratio']])
# Out:
# Top 15 Overvalued Players:
#              Full_Name       nPER  2022_23_Salary   Value_Ratio
# 253         Tyus Jones   3.026562      15000000.0  2.017708e-07
# 215     Richaun Holmes   2.697906      11215260.0  2.405567e-07
# 455        Ben Simmons   9.648759      35448672.0  2.721896e-07
# 167        Eric Gordon   6.570806      19568360.0  3.357873e-07
# 206     Gordon Hayward  10.663908      30075000.0  3.545772e-07
# 331  Jordan McLaughlin   0.835588       2160000.0  3.868461e-07
# 216         Al Horford  10.978851      26500000.0  4.142963e-07
# 288      Kawhi Leonard  17.814225      42492492.0  4.192323e-07
# 43       Davis Bertans   6.890775      16000000.0  4.306735e-07
# 84        Jimmy Butler  16.698386      37653300.0  4.434774e-07
# 1         Steven Adams   8.062026      17926829.0  4.497184e-07
# 238       LeBron James  22.562625      44474988.0  5.073104e-07
# 457       Jericho Sims   0.870059       1639842.0  5.305747e-07
# 426  Mitchell Robinson   9.460942      17045454.0  5.550420e-07
# 38        Bradley Beal  24.586943      43279250.0  5.681000e-07
#
# Top 15 Undervalued Players:
#              Full_Name       nPER  2022_23_Salary  Value_Ratio
# 419           Naz Reid  32.663898       1930681.0     0.000017
# 29        Desmond Bane  34.321489       2130240.0     0.000016
# 324    Jaden McDaniels  34.633553       2161440.0     0.000016
# 470          Max Strus  28.924921       1815677.0     0.000016
# 398       Jordan Poole  59.580971       3901399.0     0.000015
# 411  Immanuel Quickley  33.790747       2316240.0     0.000015
# 10       Jose Alvarado  22.668188       1563518.0     0.000014
# 500       Gabe Vincent  25.507270       1815677.0     0.000014
# 193        Jaden Hardy  14.016498       1017781.0     0.000014
# 127        Ayo Dosunmu  21.026604       1563518.0     0.000013
# 504      Moritz Wagner  24.502787       1878720.0     0.000013
# 449     Alperen Sengun  42.700625       3375360.0     0.000013
# 325    Jalen McDaniels  24.363749       1930681.0     0.000013
# 278       Jock Landale  18.760273       1563518.0     0.000012
# 364    Andrew Nembhard  24.492918       2244111.0     0.000011
